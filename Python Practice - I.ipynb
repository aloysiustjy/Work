# %% [markdown]
# # Ticket Pricing
#
# Create a Python program that calculates the price of a movie ticket based on the age of the moviegoer and whether it's a matinee show or not. Ask the user for their age and whether it's a matinee show (True or False). Use nested conditionals to determine the ticket price:
#
# If the age is below 12 or above 65, the ticket price is $5.
#
# If it's a matinee show (before 5 PM) and the age is between 12 and 65, the ticket price is $7.
#
# If it's not a matinee show and the age is between 12 and 65, the ticket price is $10.

# %% [markdown]
# # Print Even Numbers
# Write a Python program that uses a while loop to print the first 10 even numbers (starting from 2)

# %% [markdown]
# # Calculator
#
# Write a Python program that simulates a basic calculator. The program should prompt the user to enter two numbers and an arithmetic operation (+, -, , /). Perform the requested operation on the two numbers and display the result. Ensure that the program handles division by zero gracefully.

# %% [markdown]
# # Delivery Charges
# Write a Python program that calculates the delivery charges for an online order based on the order total and the user's membership status. Ask the user for the order total and whether they have a premium membership (True or False). Use nested conditionals to determine the delivery charges:
#
# If the order total is $50 or more, and the user has a premium membership, the delivery is free.
#
# If the order total is $100 or more, but the user does not have a premium membership, the delivery is free.
#
# For orders less than $50,
#  the deliver charge is $10 for users without premium membership and $5 for users with premium membership.

# %% [markdown]
# # Guessing Game
# Write Python code that simulates a simple guessing game. Generate a random number between 1 and 100 and ask the user to guess it. Use a while True loop to repeatedly prompt the user for guesses until they correctly guess the number. Provide feedback on whether their guess is too high or too low.

# %% [markdown]
# # Unit Converter
#
# Create a program that converts units of measurement (e.g., temperature from Celsius to Fahrenheit, length from meters to feet).

# %% [markdown]
# # BMI Calculator
# Develop a Body Mass Index (BMI) calculator that takes a user's weight and height and calculates their BMI using the formula:
# BMI=weight (kg)/(height (m))**2

# %% [markdown]
# # Area and Perimeter
# Write a program that calculates the area and perimeter of different shapes (e.g., rectangle, circle, triangle) using appropriate mathematical formulas.

# %% [markdown]
# # Simple Interest Calculator
# Write a program that calculates the simple interest earned or paid on a loan or investment using the formula:
# Simple Interest =𝑃×𝑅×𝑇 / 100
#  , where
# 𝑃 is the principal amount,
# 𝑅
# is the rate of interest per year, and
# 𝑇
# is the time period in years.

# %% [markdown]
# # Voting Eligibility Checker
#
# Develop a program that takes a user's age as input and determines if they are eligible to vote (e.g., age >= 18).
