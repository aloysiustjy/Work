# %% [markdown]
# # Analyze Stock Prices:
# Given a list of daily stock prices, write a program to calculate the maximum profit that could have been made by buying on one day and selling on another day.

# %%
prices = [7, 1, 5, 3, 6, 4]
# Output: 5 (buy at 1, sell at 6)

# %% [markdown]
# # Customer Feedback Analysis:
# Given a list of customer feedback comments, write a program to count the number of positive and negative comments. Assume that positive comments contain the word "good" and negative comments contain the word "bad".

# %%
feedback = ["The product is good", "Service was bad", "Good quality", "Bad experience"]
# Output: Positive: 2, Negative: 2

# %% [markdown]
# # Temperature Monitoring:
# Given a list of daily temperatures, write a program to find the longest streak of days with temperatures above a certain threshold.

# %%
temperatures = [72, 75, 79, 80, 81, 68, 70, 76, 78]
threshold = 75
# Output: 5 (streak of 79, 80, 81, 76, 78)

# %% [markdown]
# # Library Book Tracking:
# Given a list of book IDs and a list of borrowed book IDs, write a program to find the IDs of the books that are currently not borrowed.

# %%
book_ids = [101, 102, 103, 104, 105]
borrowed_ids = [102, 104]
# Output: [101, 103, 105]

# %% [markdown]
# # Event Attendance:
# Given a list of event attendees and a list of VIP attendees, write a program to identify which VIPs did not attend the event.

# %%
attendees = ["Alice", "Bob", "Charlie"]
vip_attendees = ["Bob", "Dave"]
# Output: ["Dave"]

# %% [markdown]
# # Sales Data Analysis:
# Given a list of daily sales figures, write a program to calculate the average sales and identify the days with sales above average.

# %%
sales = [100, 150, 200, 50, 300]
# Output: Average: 160, Days above average: [150, 200, 300]

# %% [markdown]
# # Student Grade Analysis:
# Given a list of student grades, write a program to find the highest and lowest grades and the number of students who scored above a certain grade.

# %%
grades = [88, 92, 79, 85, 91]
threshold = 90
# Output: Highest: 92, Lowest: 79, Above 90: 2

# %% [markdown]
# # Election Vote Counting:
# Given a list of votes for candidates in an election, write a program to count the number of votes each candidate received.

# %%
votes = ["Alice", "Bob", "Alice", "Charlie", "Bob", "Bob"]
# Output: {'Alice': 2, 'Bob': 3, 'Charlie': 1}

# %% [markdown]
# # Flight Booking System:
# Given a list of booked seats on a flight and the total number of seats, write a program to find the available seats.

# %%
total_seats = 10
booked_seats = [1, 3, 5, 7]
# Output: [0, 2, 4, 6, 8, 9]

# %% [markdown]
# # Grocery Store Inventory:
# Given a list of items in stock and a list of items sold, write a program to update the stock list.

# %%
stock = ["apples", "bananas", "oranges", "grapes"]
sold = ["bananas", "grapes"]
# Output: ["apples", "oranges"]
