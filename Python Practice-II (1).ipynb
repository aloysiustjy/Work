# %% [markdown]
# # Sum of Numbers
# Write a program that calculates the sum of all numbers from 1 to 100 using a loop.

# %% [markdown]
# # Factorial Calculation
# Write a program that calculates the factorial of a given number n. The factorial of n is the product of all positive integers up to n (n!).

# %% [markdown]
# # Multiplication Table
# Write a program that prints the multiplication table for a given number n. The table should include multiples from 1 to 10.

# %% [markdown]
# # List Reversal
# Write a program that reverses a given list of integers without using built-in reverse functions.

# %% [markdown]
# # Count Vowels
# Write a program that counts the number of vowels in a given string. Vowels are 'a', 'e', 'i', 'o', 'u'.

# %% [markdown]
# # Prime Numbers
# Write a program that prints all prime numbers between 1 and 100.

# %% [markdown]
# # Fibonacci Sequence
# Write a program that prints the first n numbers in the Fibonacci sequence. The Fibonacci sequence is characterized by the fact that every number after the first two is the sum of the two preceding ones.

# %% [markdown]
# # Pattern Printing
# Write a program that prints the following pattern for a given number n:
#
# ```
# *
# **
# ***
# ****
# *****
# ```

# %% [markdown]
# # Find the Largest Number
# Write a program that finds the largest number in a given list of integers.

# %% [markdown]
# # Sum of Digits
# Write a program that calculates the sum of the digits of a given number. For example, if the input is 123, the output should be 6 (1 + 2 + 3).
